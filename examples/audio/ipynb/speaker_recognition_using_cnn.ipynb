# %% [markdown]
# <a href="https://colab.research.google.com/github/Sawantyash12/Speaker-Recognition/blob/main/examples/audio/ipynb/speaker_recognition_using_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Speaker Recognition
#
# **Author:** [Fadi Badine](https://twitter.com/fadibadine)<br>
# **Date created:** 14/06/2020<br>
# **Last modified:** 19/07/2023<br>
# **Description:** Classify speakers using Fast Fourier Transform (FFT) and a 1D Convnet.

# %% [markdown]
# ## Introduction
#
# This example demonstrates how to create a model to classify speakers from the
# frequency domain representation of speech recordings, obtained via Fast Fourier
# Transform (FFT).
#
# It shows the following:
#
# - How to use `tf.data` to load, preprocess and feed audio streams into a model
# - How to create a 1D convolutional network with residual
# connections for audio classification.
#
# Our process:
#
# - We prepare a dataset of speech samples from different speakers, with the speaker as label.
# - We add background noise to these samples to augment our data.
# - We take the FFT of these samples.
# - We train a 1D convnet to predict the correct speaker given a noisy FFT speech sample.
#
# Note:
#
# - This example should be run with TensorFlow 2.3 or higher, or `tf-nightly`.
# - The noise samples in the dataset need to be resampled to a sampling rate of 16000 Hz
# before using the code in this example. In order to do this, you will need to have
# installed `ffmpg`.

# %% [markdown]
# ## Setup

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import shutil
import numpy as np

import tensorflow as tf
import keras

from pathlib import Path
from IPython.display import display, Audio

# Get the data from https://www.kaggle.com/kongaevans/speaker-recognition-dataset/
# and save it to ./speaker-recognition-dataset.zip
# then unzip it to ./16000_pcm_speeches

# %%
# !kaggle datasets download -d avishkar001/iemocap-team-noob
# !unzip iemocap-team-noob.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/avishkar001/iemocap-team-noob
# License(s): unknown
# Downloading iemocap-team-noob.zip to /content
#  99% 193M/195M [00:01<00:00, 153MB/s]
# 100% 195M/195M [00:01<00:00, 127MB/s]
# Archive:  iemocap-team-noob.zip
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-01.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-02.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-03.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-04.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-05.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-06.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-07.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-08.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-09.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-10.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-100.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-101.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-102.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-103.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-104.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-105.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-106.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-107.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-108.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-109.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-11.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-110.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-111.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-112.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-113.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-114.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-115.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-116.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-117.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-118.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-119.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-12.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-120.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-121.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-122.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-123.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-124.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-125.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-126.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-127.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-128.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-129.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-13.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-130.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-131.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-132.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-133.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-134.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-135.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-136.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-137.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-138.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-139.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-14.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-140.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-141.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-142.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-143.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-144.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-145.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-146.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-147.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-148.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-149.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-15.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-150.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-151.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-152.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-153.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-154.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-155.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-156.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-157.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-158.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-159.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-16.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-160.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-161.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-162.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-163.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-164.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-165.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-166.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-167.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-168.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-169.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-17.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-170.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-171.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-172.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-173.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-174.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-175.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-176.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-177.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-178.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-179.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-18.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-180.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-181.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-182.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-183.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-184.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-185.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-186.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-187.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-188.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-189.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-19.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-190.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-191.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-192.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-193.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-194.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-195.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-196.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-197.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-198.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-199.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-20.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-200.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-201.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-202.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-203.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-204.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-205.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-206.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-207.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-208.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-209.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-21.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-210.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-211.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-212.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-213.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-214.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-215.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-216.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-217.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-218.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-219.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-22.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-220.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-221.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-222.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-223.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-224.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-225.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-226.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-227.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-228.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-229.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-23.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-230.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-231.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-232.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-233.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-234.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-235.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-236.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-237.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-238.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-239.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-24.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-240.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-241.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-242.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio-243.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 1/audio
wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-333.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-334.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-335.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-336.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-337.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-338.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-339.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-34.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-340.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-341.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-342.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-343.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-344.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-345.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-346.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-347.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-348.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-349.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-35.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-350.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-351.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-352.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-353.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-354.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-355.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-356.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-357.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-358.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-359.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-36.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-360.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-361.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-362.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-363.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-364.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-365.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-366.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-367.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-368.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-369.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-37.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-370.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-371.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-372.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-373.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-374.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-375.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-376.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-377.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-378.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-379.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-38.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-380.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-381.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-382.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-383.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-384.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-385.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-386.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-387.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-388.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-389.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-39.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-390.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-391.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-392.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-393.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-394.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-395.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-396.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-397.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-398.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-399.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-40.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-400.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-401.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-402.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-403.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-404.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-405.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-406.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-407.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-408.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-409.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-41.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-410.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-411.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-412.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-413.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-414.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-415.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-416.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-417.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-418.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-419.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-42.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-420.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-421.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-422.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-423.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-424.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-425.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-426.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-427.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-428.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-429.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-43.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-430.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-431.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-432.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-433.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-434.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-435.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-436.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-437.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-438.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-439.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-44.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-440.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-441.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-442.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-443.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-444.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-445.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-446.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-447.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-448.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-449.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-45.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-450.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-451.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-452.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-453.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-454.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-455.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-456.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-457.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-458.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-459.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-46.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-460.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-47.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-48.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-49.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-50.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-51.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-52.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-53.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-54.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-55.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-56.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-57.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-58.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-59.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-60.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-61.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-62.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-63.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-64.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-65.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-66.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-67.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-68.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-69.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-70.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-71.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-72.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-73.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-74.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-75.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-76.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-77.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-78.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-79.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-80.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-81.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-82.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-83.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-84.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-85.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-86.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-87.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-88.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-89.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-90.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-91.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-92.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-93.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-94.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-95.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-96.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-97.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-98.wav
#   inflating: IEMOCAP_Team_Noob/Speaker 4/audio-99.wav
#   inflating: IEMOCAP_Team_Noob/_background_noise_/10convert.com_Audience-Claps_daSG5fwdA7o.wav
#   inflating: IEMOCAP_Team_Noob/_background_noise_/doing_the_dishes.wav
#   inflating: IEMOCAP_Team_Noob/_background_noise_/dude_miaowing.wav
#   inflating: IEMOCAP_Team_Noob/_background_noise_/running_tap.wav
#   inflating: IEMOCAP_Team_Noob/other/exercise_bike.wav
#   inflating: IEMOCAP_Team_Noob/other/pink_noise.wav

# %%
DATASET_ROOT = "IEMOCAP_Team_Noob"

# The folders in which we will put the audio samples and the noise samples
AUDIO_SUBFOLDER = "audio"
NOISE_SUBFOLDER = "noise"

DATASET_AUDIO_PATH = os.path.join(DATASET_ROOT, AUDIO_SUBFOLDER)
DATASET_NOISE_PATH = os.path.join(DATASET_ROOT, NOISE_SUBFOLDER)

# Percentage of samples to use for validation
VALID_SPLIT = 0.1

# Seed to use when shuffling the dataset and the noise
SHUFFLE_SEED = 43

# The sampling rate to use.
# This is the one used in all the audio samples.
# We will resample all the noise to this sampling rate.
# This will also be the output size of the audio wave samples
# (since all samples are of 1 second long)
SAMPLING_RATE = 16000

# The factor to multiply the noise with according to:
#   noisy_sample = sample + noise * prop * scale
#      where prop = sample_amplitude / noise_amplitude
SCALE = 0.5

BATCH_SIZE = 128
EPOCHS = 1  # For a real training run, use EPOCHS = 100

# %% [markdown]
# ## Data preparation
#
# The dataset is composed of 7 folders, divided into 2 groups:
#
# - Speech samples, with 5 folders for 5 different speakers. Each folder contains
# 1500 audio files, each 1 second long and sampled at 16000 Hz.
# - Background noise samples, with 2 folders and a total of 6 files. These files
# are longer than 1 second (and originally not sampled at 16000 Hz, but we will resample them to 16000 Hz).
# We will use those 6 files to create 354 1-second-long noise samples to be used for training.
#
# Let's sort these 2 categories into 2 folders:
#
# - An `audio` folder which will contain all the per-speaker speech sample folders
# - A `noise` folder which will contain all the noise samples

# %% [markdown]
# Before sorting the audio and noise categories into 2 folders,
# we have the following directory structure:
#
# ```
# main_directory/
# ...speaker_a/
# ...speaker_b/
# ...speaker_c/
# ...speaker_d/
# ...speaker_e/
# ...other/
# ..._background_noise_/
# ```
#
# After sorting, we end up with the following structure:
#
# ```
# main_directory/
# ...audio/
# ......speaker_a/
# ......speaker_b/
# ......speaker_c/
# ......speaker_d/
# ......speaker_e/
# ...noise/
# ......other/
# ......_background_noise_/
# ```

# %%
for folder in os.listdir(DATASET_ROOT):
    if os.path.isdir(os.path.join(DATASET_ROOT, folder)):
        if folder in [AUDIO_SUBFOLDER, NOISE_SUBFOLDER]:
            # If folder is `audio` or `noise`, do nothing
            continue
        elif folder in ["other", "_background_noise_"]:
            # If folder is one of the folders that contains noise samples,
            # move it to the `noise` folder
            shutil.move(
                os.path.join(DATASET_ROOT, folder),
                os.path.join(DATASET_NOISE_PATH, folder),
            )
        else:
            # Otherwise, it should be a speaker folder, then move it to
            # `audio` folder
            shutil.move(
                os.path.join(DATASET_ROOT, folder),
                os.path.join(DATASET_AUDIO_PATH, folder),
            )

# %% [markdown]
# ## Noise preparation
#
# In this section:
#
# - We load all noise samples (which should have been resampled to 16000)
# - We split those noise samples to chunks of 16000 samples which
# correspond to 1 second duration each

# %%
# Get the list of all noise files
noise_paths = []
for subdir in os.listdir(DATASET_NOISE_PATH):
    subdir_path = Path(DATASET_NOISE_PATH) / subdir
    if os.path.isdir(subdir_path):
        noise_paths += [
            os.path.join(subdir_path, filepath)
            for filepath in os.listdir(subdir_path)
            if filepath.endswith(".wav")
        ]
if not noise_paths:
    raise RuntimeError(f"Could not find any files at {DATASET_NOISE_PATH}")
print(
    "Found {} files belonging to {} directories".format(
        len(noise_paths), len(os.listdir(DATASET_NOISE_PATH))
    )
)
# Out:
# Found 6 files belonging to 2 directories

# %% [markdown]
# Resample all noise samples to 16000 Hz

# %%
command = (
    "for dir in `ls -1 " + DATASET_NOISE_PATH + "`; do "
    "for file in `ls -1 " + DATASET_NOISE_PATH + "/$dir/*.wav`; do "
    "sample_rate=`ffprobe -hide_banner -loglevel panic -show_streams "
    "$file | grep sample_rate | cut -f2 -d=`; "
    "if [ $sample_rate -ne 16000 ]; then "
    "ffmpeg -hide_banner -loglevel panic -y "
    "-i $file -ar 16000 temp.wav; "
    "mv temp.wav $file; "
    "fi; done; done"
)
os.system(command)


# Split noise into chunks of 16,000 steps each
def load_noise_sample(path):
    sample, sampling_rate = tf.audio.decode_wav(
        tf.io.read_file(path), desired_channels=1
    )
    if sampling_rate == SAMPLING_RATE:
        # Number of slices of 16000 each that can be generated from the noise sample
        slices = int(sample.shape[0] / SAMPLING_RATE)
        sample = tf.split(sample[: slices * SAMPLING_RATE], slices)
        return sample
    else:
        print("Sampling rate for {} is incorrect. Ignoring it".format(path))
        return None


noises = []
for path in noise_paths:
    sample = load_noise_sample(path)
    if sample:
        noises.extend(sample)
noises = tf.stack(noises)

print(
    "{} noise files were split into {} noise samples where each is {} sec. long".format(
        len(noise_paths), noises.shape[0], noises.shape[1] // SAMPLING_RATE
    )
)
# Out:
# 6 noise files were split into 354 noise samples where each is 1 sec. long

# %% [markdown]
# ## Dataset generation

# %%
def paths_and_labels_to_dataset(audio_paths, labels):
    """Constructs a dataset of audios and labels."""
    path_ds = tf.data.Dataset.from_tensor_slices(audio_paths)
    audio_ds = path_ds.map(
        lambda x: path_to_audio(x), num_parallel_calls=tf.data.AUTOTUNE
    )
    label_ds = tf.data.Dataset.from_tensor_slices(labels)
    return tf.data.Dataset.zip((audio_ds, label_ds))


def path_to_audio(path):
    """Reads and decodes an audio file."""
    audio = tf.io.read_file(path)
    audio, _ = tf.audio.decode_wav(audio, 1, SAMPLING_RATE)
    return audio


def add_noise(audio, noises=None, scale=0.5):
    if noises is not None:
        # Create a random tensor of the same size as audio ranging from
        # 0 to the number of noise stream samples that we have.
        tf_rnd = tf.random.uniform(
            (tf.shape(audio)[0],), 0, noises.shape[0], dtype=tf.int32
        )
        noise = tf.gather(noises, tf_rnd, axis=0)

        # Get the amplitude proportion between the audio and the noise
        prop = tf.math.reduce_max(audio, axis=1) / tf.math.reduce_max(noise, axis=1)
        prop = tf.repeat(tf.expand_dims(prop, axis=1), tf.shape(audio)[1], axis=1)

        # Adding the rescaled noise to audio
        audio = audio + noise * prop * scale

    return audio


def audio_to_fft(audio):
    # Since tf.signal.fft applies FFT on the innermost dimension,
    # we need to squeeze the dimensions and then expand them again
    # after FFT
    audio = tf.squeeze(audio, axis=-1)
    fft = tf.signal.fft(
        tf.cast(tf.complex(real=audio, imag=tf.zeros_like(audio)), tf.complex64)
    )
    fft = tf.expand_dims(fft, axis=-1)

    # Return the absolute value of the first half of the FFT
    # which represents the positive frequencies
    return tf.math.abs(fft[:, : (audio.shape[1] // 2), :])


# Get the list of audio file paths along with their corresponding labels

class_names = os.listdir(DATASET_AUDIO_PATH)
print(
    "Our class names: {}".format(
        class_names,
    )
)

audio_paths = []
labels = []
for label, name in enumerate(class_names):
    print(
        "Processing speaker {}".format(
            name,
        )
    )
    dir_path = Path(DATASET_AUDIO_PATH) / name
    speaker_sample_paths = [
        os.path.join(dir_path, filepath)
        for filepath in os.listdir(dir_path)
        if filepath.endswith(".wav")
    ]
    audio_paths += speaker_sample_paths
    labels += [label] * len(speaker_sample_paths)

print(
    "Found {} files belonging to {} classes.".format(len(audio_paths), len(class_names))
)

# Shuffle
rng = np.random.RandomState(SHUFFLE_SEED)
rng.shuffle(audio_paths)
rng = np.random.RandomState(SHUFFLE_SEED)
rng.shuffle(labels)

# Split into training and validation
num_val_samples = int(VALID_SPLIT * len(audio_paths))
print("Using {} files for training.".format(len(audio_paths) - num_val_samples))
train_audio_paths = audio_paths[:-num_val_samples]
train_labels = labels[:-num_val_samples]

print("Using {} files for validation.".format(num_val_samples))
valid_audio_paths = audio_paths[-num_val_samples:]
valid_labels = labels[-num_val_samples:]

# Create 2 datasets, one for training and the other for validation
train_ds = paths_and_labels_to_dataset(train_audio_paths, train_labels)
train_ds = train_ds.shuffle(buffer_size=BATCH_SIZE * 8, seed=SHUFFLE_SEED).batch(
    BATCH_SIZE
)

valid_ds = paths_and_labels_to_dataset(valid_audio_paths, valid_labels)
valid_ds = valid_ds.shuffle(buffer_size=32 * 8, seed=SHUFFLE_SEED).batch(32)


# Add noise to the training set
train_ds = train_ds.map(
    lambda x, y: (add_noise(x, noises, scale=SCALE), y),
    num_parallel_calls=tf.data.AUTOTUNE,
)

# Transform audio wave to the frequency domain using `audio_to_fft`
train_ds = train_ds.map(
    lambda x, y: (audio_to_fft(x), y), num_parallel_calls=tf.data.AUTOTUNE
)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)

valid_ds = valid_ds.map(
    lambda x, y: (audio_to_fft(x), y), num_parallel_calls=tf.data.AUTOTUNE
)
valid_ds = valid_ds.prefetch(tf.data.AUTOTUNE)
# Out:
# Our class names: ['Speaker 3', 'Speaker 1', 'Speaker 2', 'Speaker 4']
# Processing speaker Speaker 3
# Processing speaker Speaker 1
# Processing speaker Speaker 2
# Processing speaker Speaker 4
# Found 1750 files belonging to 4 classes.
# Using 1575 files for training.
# Using 175 files for validation.

# %% [markdown]
# ## Model Definition

# %%
def residual_block(x, filters, conv_num=3, activation="relu"):
    # Shortcut
    s = keras.layers.Conv1D(filters, 1, padding="same")(x)
    for i in range(conv_num - 1):
        x = keras.layers.Conv1D(filters, 3, padding="same")(x)
        x = keras.layers.Activation(activation)(x)
    x = keras.layers.Conv1D(filters, 3, padding="same")(x)
    x = keras.layers.Add()([x, s])
    x = keras.layers.Activation(activation)(x)
    return keras.layers.MaxPool1D(pool_size=2, strides=2)(x)


def build_model(input_shape, num_classes):
    inputs = keras.layers.Input(shape=input_shape, name="input")

    x = residual_block(inputs, 16, 2)
    x = residual_block(x, 32, 2)
    x = residual_block(x, 64, 3)
    x = residual_block(x, 128, 3)
    x = residual_block(x, 128, 3)

    x = keras.layers.AveragePooling1D(pool_size=3, strides=3)(x)
    x = keras.layers.Flatten()(x)
    x = keras.layers.Dense(256, activation="relu")(x)
    x = keras.layers.Dense(128, activation="relu")(x)

    outputs = keras.layers.Dense(num_classes, activation="softmax", name="output")(x)

    return keras.models.Model(inputs=inputs, outputs=outputs)


model = build_model((SAMPLING_RATE // 2, 1), len(class_names))

model.summary()

# Compile the model using Adam's default learning rate
model.compile(
    optimizer="Adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# Add callbacks:
# 'EarlyStopping' to stop training when the model is not enhancing anymore
# 'ModelCheckPoint' to always keep the model that has the best val_accuracy
model_save_filename = "model.keras"

earlystopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
mdlcheckpoint_cb = keras.callbacks.ModelCheckpoint(
    model_save_filename, monitor="val_accuracy", save_best_only=True
)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input (InputLayer)          [(None, 8000, 1)]            0         []
#
#  conv1d_1 (Conv1D)           (None, 8000, 16)             64        ['input[0][0]']
#
#  activation (Activation)     (None, 8000, 16)             0         ['conv1d_1[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 8000, 16)             784       ['activation[0][0]']
#
#  conv1d (Conv1D)             (None, 8000, 16)             32        ['input[0][0]']
#
#  add (Add)                   (None, 8000, 16)             0         ['conv1d_2[0][0]',
#                                                                      'conv1d[0][0]']
#
#  activation_1 (Activation)   (None, 8000, 16)             0         ['add[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 4000, 16)             0         ['activation_1[0][0]']
#  D)
#
#  conv1d_4 (Conv1D)           (None, 4000, 32)             1568      ['max_pooling1d[0][0]']
#
#  activation_2 (Activation)   (None, 4000, 32)             0         ['conv1d_4[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 4000, 32)             3104      ['activation_2[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 4000, 32)             544       ['max_pooling1d[0][0]']
#
#  add_1 (Add)                 (None, 4000, 32)             0         ['conv1d_5[0][0]',
#                                                                      'conv1d_3[0][0]']
#
#  activation_3 (Activation)   (None, 4000, 32)             0         ['add_1[0][0]']
#
#  max_pooling1d_1 (MaxPoolin  (None, 2000, 32)             0         ['activation_3[0][0]']
#  g1D)
#
#  conv1d_7 (Conv1D)           (None, 2000, 64)             6208      ['max_pooling1d_1[0][0]']
#
#  activation_4 (Activation)   (None, 2000, 64)             0         ['conv1d_7[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 2000, 64)             12352     ['activation_4[0][0]']
#
#  activation_5 (Activation)   (None, 2000, 64)             0         ['conv1d_8[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 2000, 64)             12352     ['activation_5[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 2000, 64)             2112      ['max_pooling1d_1[0][0]']
#
#  add_2 (Add)                 (None, 2000, 64)             0         ['conv1d_9[0][0]',
#                                                                      'conv1d_6[0][0]']
#
#  activation_6 (Activation)   (None, 2000, 64)             0         ['add_2[0][0]']
#
#  max_pooling1d_2 (MaxPoolin  (None, 1000, 64)             0         ['activation_6[0][0]']
#  g1D)
#
#  conv1d_11 (Conv1D)          (None, 1000, 128)            24704     ['max_pooling1d_2[0][0]']
#
#  activation_7 (Activation)   (None, 1000, 128)            0         ['conv1d_11[0][0]']
#
#  conv1d_12 (Conv1D)          (None, 1000, 128)            49280     ['activation_7[0][0]']
#
#  activation_8 (Activation)   (None, 1000, 128)            0         ['conv1d_12[0][0]']
#
#  conv1d_13 (Conv1D)          (None, 1000, 128)            49280     ['activation_8[0][0]']
#
#  conv1d_10 (Conv1D)          (None, 1000, 128)            8320      ['max_pooling1d_2[0][0]']
#
#  add_3 (Add)                 (None, 1000, 128)            0         ['conv1d_13[0][0]',
#                                                                      'conv1d_10[0][0]']
#
#  activation_9 (Activation)   (None, 1000, 128)            0         ['add_3[0][0]']
#
#  max_pooling1d_3 (MaxPoolin  (None, 500, 128)             0         ['activation_9[0][0]']
#  g1D)
#
#  conv1d_15 (Conv1D)          (None, 500, 128)             49280     ['max_pooling1d_3[0][0]']
#
#  activation_10 (Activation)  (None, 500, 128)             0         ['conv1d_15[0][0]']
#
#  conv1d_16 (Conv1D)          (None, 500, 128)             49280     ['activation_10[0][0]']
#
#  activation_11 (Activation)  (None, 500, 128)             0         ['conv1d_16[0][0]']
#
#  conv1d_17 (Conv1D)          (None, 500, 128)             49280     ['activation_11[0][0]']
#
#  conv1d_14 (Conv1D)          (None, 500, 128)             16512     ['max_pooling1d_3[0][0]']
#
#  add_4 (Add)                 (None, 500, 128)             0         ['conv1d_17[0][0]',
#                                                                      'conv1d_14[0][0]']
#
#  activation_12 (Activation)  (None, 500, 128)             0         ['add_4[0][0]']
#
#  max_pooling1d_4 (MaxPoolin  (None, 250, 128)             0         ['activation_12[0][0]']
#  g1D)
#
#  average_pooling1d (Average  (None, 83, 128)              0         ['max_pooling1d_4[0][0]']
#  Pooling1D)
#
#  flatten (Flatten)           (None, 10624)                0         ['average_pooling1d[0][0]']
#
#  dense (Dense)               (None, 256)                  2720000   ['flatten[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  32896     ['dense[0][0]']
#
#  output (Dense)              (None, 4)                    516       ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 3088468 (11.78 MB)
# Trainable params: 3088468 (11.78 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training

# %%
history = model.fit(
    train_ds,
    epochs=EPOCHS,
    validation_data=valid_ds,
    callbacks=[earlystopping_cb, mdlcheckpoint_cb],
)
# Out:
# 13/13 [==============================] - 5s 259ms/step - loss: 0.0459 - accuracy: 0.9822 - val_loss: 1.4079 - val_accuracy: 0.8057

# %% [markdown]
# ## Evaluation

# %%
print(model.evaluate(valid_ds))
# Out:
# 6/6 [==============================] - 1s 26ms/step - loss: 1.4079 - accuracy: 0.8057
# [1.4078577756881714, 0.8057143092155457]

# %% [markdown]
# We get ~ 98% validation accuracy.

# %% [markdown]
# ## Demonstration
#
# Let's take some samples and:
#
# - Predict the speaker
# - Compare the prediction with the real speaker
# - Listen to the audio to see that despite the samples being noisy,
# the model is still pretty accurate

# %%
SAMPLES_TO_DISPLAY = 10

test_ds = paths_and_labels_to_dataset(valid_audio_paths, valid_labels)
test_ds = test_ds.shuffle(buffer_size=BATCH_SIZE * 8, seed=SHUFFLE_SEED).batch(
    BATCH_SIZE
)

test_ds = test_ds.map(
    lambda x, y: (add_noise(x, noises, scale=SCALE), y),
    num_parallel_calls=tf.data.AUTOTUNE,
)

for audios, labels in test_ds.take(1):
    # Get the signal FFT
    ffts = audio_to_fft(audios)
    # Predict
    y_pred = model.predict(ffts)
    # Take random samples
    rnd = np.random.randint(0, BATCH_SIZE, SAMPLES_TO_DISPLAY)
    audios = audios.numpy()[rnd, :, :]
    labels = labels.numpy()[rnd]
    y_pred = np.argmax(y_pred, axis=-1)[rnd]

    for index in range(SAMPLES_TO_DISPLAY):
        # For every sample, print the true and predicted label
        # as well as run the voice with the noise
        print(
            "Speaker:\33{} {}\33[0m\tPredicted:\33{} {}\33[0m".format(
                "[92m" if labels[index] == y_pred[index] else "[91m",
                class_names[labels[index]],
                "[92m" if labels[index] == y_pred[index] else "[91m",
                class_names[y_pred[index]],
            )
        )
        display(Audio(audios[index, :, :].squeeze(), rate=SAMPLING_RATE))
# Out:
# 4/4 [==============================] - 0s 22ms/step
# Speaker: Speaker 1	Predicted: Speaker 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Speaker 1	Predicted: Speaker 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Speaker 1	Predicted: Speaker 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Speaker 3	Predicted: Speaker 3
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Speaker 2	Predicted: Speaker 2
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Speaker 1	Predicted: Speaker 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Speaker 4	Predicted: Speaker 2
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Speaker 4	Predicted: Speaker 4
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Speaker 2	Predicted: Speaker 4
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Speaker: Speaker 3	Predicted: Speaker 3
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
